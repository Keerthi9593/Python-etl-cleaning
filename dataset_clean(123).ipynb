# %%
import pandas as pd

# %%
customers = pd.read_csv(r"C:\Users\Keerthi\Downloads\us_customer_data 1.csv")
transactions = pd.read_csv(r"C:\Users\Keerthi\Downloads\transaction_data.csv")

# %%
customers.head()
# Out:
#    customer_id              name                        email         phone  \
# 0            1     Michelle Kidd           vayala@example.net  619-723-4258
# 1            2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2            3      Larry Torres         dsanchez@example.net  810-256-4505
# 3            4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4            5  Matthew Phillips        qwilliams@example.com  220-763-3522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status
# 0           Gold
# 1         Silver
# 2         Bronze
# ...

# %%
customers.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                50
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers[customers['email'].isnull()].head()
# Out:
#     customer_id               name email         phone  \
# 27           28       Brandon Hall   NaN  974-123-3048
# 35           36  Christopher Clark   NaN  119-609-3438
# 50           51        David Garza   NaN  352-638-6388
# 73           74        Tony Romero   NaN  150-483-8748
# 74           75        Haley Jones   NaN  843-161-5799
#
#                                               address registration_date  \
# 27   8143 Robert Cove Apt. 103, Sanchezport, CO 78231        07-04-2024
# 35  2325 Danielle Knolls Suite 719, Gabrielleview,...        13-01-2024
# 50                         USS Williams, FPO AA 77634        24-10-2023
# 73  92893 Lopez Key Apt. 330, South Latasha, NJ 01621        01-08-2023
# 74    43986 Frost Forge, East Michellemouth, FL 84797        27-12-2024
#
#    loyalty_status
# 27           Gold
# 35           Gold
# 50         Silver
# 73           Gold
# 74           Gold

# %%
customers[customers['phone'].isnull()].head()
# Out:
#      customer_id              name                       email phone  \
# 306          307     Courtney Reed        xhopkins@example.net   NaN
# 377          378     Michael Singh      jennifer95@example.net   NaN
# 382          383      Miranda Pham    aliciamorris@example.com   NaN
# 393          394    Michael Juarez  deborahschmitt@example.com   NaN
# 399          400  Alejandro Romero         david51@example.com   NaN
#
#                                               address registration_date  \
# 306  8858 Joshua Square Suite 148, Johnbury, OH 85434        04-09-2024
# 377          97409 Joshua Rapids, Bakerport, GA 23426        25-10-2024
# 382     8282 Mary Forest Apt. 281, Amymouth, WI 71635        13-07-2023
# 393          065 Huffman Flat, East Michael, NH 86560        09-06-2024
# 399  303 Garcia Extension, Lake Rebeccaberg, MO 28901        12-10-2024
#
#     loyalty_status
# 306           Gold
# 377         Silver
# 382         Silver
# 393         Silver
# ...

# %%
customers['email'] = customers['email'].fillna(customers['name'].str.lower().str.replace(' ', '')+'@example.com')

# %%
customers[['email']].loc[35]
# Out:
# email    christopherclark@example.com
# Name: 35, dtype: object

# %%
customers['phone']= customers['phone'].str.replace(r'[^0-9]', '',regex=True) 
customers['phone']= customers['phone'].str.slice(0,10)

# %%
customers.loc[customers['phone'].str.len() < 10, 'phone'] = 'xxx-xxx-xxxx' #replacing short numbers
customers['phone'] = customers['phone'].fillna('xxx-xxx-xxxx')

# %%
customers[['phone']].loc[306]
# Out:
# phone    xxx-xxx-xxxx
# Name: 306, dtype: object

# %%
customers['phone'] = customers['phone'].str.replace('-', '')

# %%
customers[['phone']].loc[306]
# Out:
# phone    xxxxxxxxxx
# Name: 306, dtype: object

# %%
customers.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# dtype: int64

# %%
customers[['registration_date']]
# Out:
#     registration_date
# 0          25-01-2025
# 1          13-07-2023
# 2          18-08-2023
# 3          08-12-2024
# 4          03-02-2024
# ..                ...
# 995        10-02-2025
# 996        18-04-2024
# 997        30-08-2024
# 998        16-05-2024
# 999        10-12-2024
#
# [1000 rows x 1 columns]

# %%
customers['phone'] = '+91'+ '-'+ customers['phone']

# %%
customers[['phone']].loc[306]
# Out:
# phone    +91-xxxxxxxxxx
# Name: 306, dtype: object

# %%
customers['name'] = customers['name'].str.title()

# %%
customers['name'].head()
# Out:
# 0       Michelle Kidd
# 1         Brad Newton
# 2        Larry Torres
# 3      Kimberly Price
# 4    Matthew Phillips
# Name: name, dtype: object

# %%
merged_table = pd.merge(customers, transactions, on ='customer_id', how = 'inner')
print(merged_table)
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 4              7      Louis Miller  patriciaelliott@example.org
# ..           ...               ...                          ...
# 995          995    Deanna Johnson            ycook@example.org
# 996          995    Deanna Johnson            ycook@example.org
# 997          997      Jodi Simpson           eric24@example.org
# 998          998     Crystal Brown         pshaffer@example.net
# 999          998     Crystal Brown         pshaffer@example.net
#
#               phone                                            address  \
# 0    +91-6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
merged_table.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                 0
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount               50
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
transactions_above_1000 = merged_table[merged_table['amount'] > 1000]

# %%
transactions_above_1000
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 6             10      Rachel White     whitemichael@example.org
# ..           ...               ...                          ...
# 990          991     Erica Fleming          erica85@example.net
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org
# 993          995    Deanna Johnson            ycook@example.org
# 994          995    Deanna Johnson            ycook@example.org
#
#               phone                                            address  \
# 0    +91-6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
above_mean = merged_table[merged_table['amount'] > merged_table['amount'].mean()]

# %%
above_mean
# Out:
#      customer_id               name                        email  \
# 0              1      Michelle Kidd           vayala@example.net
# 3              7       Louis Miller  patriciaelliott@example.org
# 6             10       Rachel White     whitemichael@example.org
# 7             10       Rachel White     whitemichael@example.org
# 9             12  Christine Delgado         yfarrell@example.net
# ..           ...                ...                          ...
# 990          991      Erica Fleming          erica85@example.net
# 991          991      Erica Fleming          erica85@example.net
# 992          992     Thomas Stevens    vargasmatthew@example.org
# 993          995     Deanna Johnson            ycook@example.org
# 994          995     Deanna Johnson            ycook@example.org
#
#               phone                                            address  \
# 0    +91-6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
customers.drop_duplicates(subset = 'customer_id', keep ='first')
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#               phone                                            address  \
# 0    +91-6197234258                        USNS Santiago, FPO AE 80872
# ...
